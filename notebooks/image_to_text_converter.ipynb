# %% [markdown]
# ## Install tesseract
#
# In the command line on MAC, run this command on Mac fpr tesseract command line:
#
# `brew install tesseract`
#
# https://pypi.org/project/pytesseract/#history

# %%
! apt install tesseract-ocr
! apt install libtesseract-dev

# %%
! pip install Pillow
! pip install pytesseract

# %% [markdown]
# ## Show the snapshot

# %%
from IPython.display import Image

fn = "../data/screenshot.jpg"
Image(filename=fn)

# %% [markdown]
# ## Run OCR using tesseract

# %%
import pytesseract
from PIL import ImageEnhance, ImageFilter, Image
# Out:
# //anaconda/envs/uatu/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
pytesseract.pytesseract.tesseract_cmd = r'/usr/local/bin/tesseract'
# pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'
# pytesseract.pytesseract.tesseract_cmd = r'/usr/local/bin/pytesseract'

img = r"../data/screenshot.jpg"

# Convert image to string
print(pytesseract.image_to_string(Image.open(img)))
# Out:
#
#
# 14 Leaders
#
# The Federal Reserve
#
# Wind down the mo?
#
# Why America’s economy needs t!
#
# 7 E FEDERAL RESERVE has spent most of 2021 saying that high
#
# inflation would be temporary. And yet price rises have per-
# sistently overshot forecasts, reaching 5% in October, on the Fed’s
# preferred measure, even as employment remains about 4m
# short of its pre-pandemic level. On December 15th the Fed will
# decide whether to tighten monetary policy, probably by acceler-
# ating the pace at which it “tapers” its monthly purchases of as-
# sets, mostly government bonds, which are currently running at
# $9o0bn per month. It should go ahead and take action. Though
# uncertainty is high, the Fed must rapidly respond to the data it
# has today and then adjust as necessary as conditions evolve.
# Those data indicate that it has already fallen behind.
#
# The rise in prices cannot be explained by a few shortages,
# such as of second-hand cars. In October the me-
# dian item in the consumer-price index was 3.1%
# more expensive than a year earlier. Clothes
# prices were up 4.3%, shelter (such as rent) was
# 3.5% dearer, and transport cost 4.5% more. In
# the third quarter private-sector wages and sala-
# ries grew at an annualised rate of 6.5% —too fast
# to be compatible with the Fed's 2% inflation tar-
# get without incredible productivity growth.
#
# It is true that temporary factors have driven up inflation. The
# $1.9trn fiscal stimulus President Joe Biden signed in March will
# not be repeated (the outlay proposed in the Democrats’ social-
# spending bill is more spread out and partly offset by tax rises).
# During the pandemic, consumers have binged on goods. Supply
# chains have been bunged up, especially as the world’s factories
# have faced lockdowns and staff absences, Despite an abnormal
# number of Americans out of work, firms have struggled to fill va-
# cancies (see Finance and economics section).
#
# However, predicting when these pandemic-related forces
# will ease is a fool's errand, especially now that the Omicron var-
# iant is spreading. For as long as inflation remains high, there isa
# growing danger that it will become entrenched, The New York
#
# 2019
#
# PCE price index
# United States, January 2019=100
#
# 2% inflation
# ingnatiinethenaadiieis omens target a
#
# 20
#
# —_—
#
# es
#
# —
#
# _——_ The Economist December
#
# ey printer
#
# policy
# median consumer expects prices ty .: :
# over the next three years, up fron, hin
# g they may demand higher Wages pi.
# tions also reduce the effective cost of credit
# kes debts easier to repay. The real interes,
# vernment bonds is about -1.6%, lower
# when the economy was far weaker,
# t from some doves is Re Nominal ¢pp ,,
# ‘ao in the economy, is merely on its pre-cy,.:
#
# Biel al rt nandemiieselaiad distortions, —
# oe demand, have driven up pr ices, they say. Yet though this x.
# gument held in the third quarter, it may already be out of da:
# Nominal cp is expected to grow at annual rates of Over 10% in
# the fourth quarter, compared with the trey
# rate of just 4%. America is seeing an unusual
# surge in demand, not just constrained supply.
#
# Tighter monetary policy is therefore jusi-
# fied. But if you believe the Fed’s theory of how
# its asset purchases work, every bond it buys
# adds fresh stimulus to the economy. It follows
# that merely tapering the pace of purchases is
# : not tightening. So why not raise interest rates
# ee uae is that the Fed is bound by its past guidance
# would ae Sete bends betas raising Fates = =
# framework would a rege OEE — a
# trustworthiness eee me = aoe: he cca ~~
# al interest-rate ina cL
#
# Ses In 2022.
#
# The good news ;
# ar, Is tha
# Talse interest rat t the Fed
#
# ghter monetary
#
# he
# ates that t
# se of 4.2%
#
# ggestin
#
# Fed esti
# an annual pace
# January 2021, SU
# inflation expecta
# cause inflation ma
# over five years on go
# in almost all of 2020,
#
# The latest argumen
#
#
#
#
#
#
#
# 21
#
#
#
# can taper fast enough tole"
# *s In March. If between now and then the
#
# demic great
# Y Wors ‘ :
# 800ds or many m “NS, consumers slash their spending
#
# lary policymak, 'ssing Workers return to the labour force,
#
# themselves sco seh ean Change course again. But they must gt
#
# tion that Would airean’® atespnens Inenddealinertdits 7
# ybeon the table. =
