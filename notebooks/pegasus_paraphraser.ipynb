# %% [markdown]
# <a href="https://colab.research.google.com/github/kjahan/armory/blob/main/notebooks/pegasus_paraphraser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Paraphraser using PEGASUS
#
# PEGASUS fine-tuned for paraphrasing
#
# Ref: https://huggingface.co/tuner007/pegasus_paraphrase

# %% [markdown]
# ## Install dependencies

# %%
# !pip install transformers[sentencepiece]
# Out:
# Collecting transformers[sentencepiece]
#   Downloading transformers-4.15.0-py3-none-any.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 4.2 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 48.6 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (2.23.0)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 35.3 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (4.62.3)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 51.1 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (3.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (4.8.2)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.2.1-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 485 kB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (1.19.5)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (3.17.3)
# Collecting sentencepiece!=0.1.92,>=0.1.91
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 51.2 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers[sentencepiece]) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers[sentencepiece]) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers[sentencepiece]) (3.6.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf->transformers[sentencepiece]) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]) (1.24.3)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers[sentencepiece]) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers[sentencepiece]) (1.1.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers, sentencepiece
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.2.1 pyyaml-6.0 sacremoses-0.0.46 sentencepiece-0.1.96 tokenizers-0.10.3 transformers-4.15.0

# %%
import torch
from transformers import PegasusForConditionalGeneration, PegasusTokenizer

# %% [markdown]
# ## Download model & set Device

# %%
model_name = 'tuner007/pegasus_paraphrase'
torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'

print("torch device: {}".format(torch_device))

tokenizer = PegasusTokenizer.from_pretrained(model_name)
model = PegasusForConditionalGeneration.from_pretrained(model_name).to(torch_device)
# Out:
# torch device: cuda
# Downloading:   0%|          | 0.00/1.82M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/86.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.12G [00:00<?, ?B/s]

# %% [markdown]
# ## Get output

# %%
def get_response(input_text, num_return_sequences, num_beams):
  batch = tokenizer([input_text],truncation=True,padding='longest', max_length=60, return_tensors="pt").to(torch_device)
  translated = model.generate(**batch, max_length=60, num_beams=num_beams, num_return_sequences=num_return_sequences, temperature=1.5)
  tgt_text = tokenizer.batch_decode(translated, skip_special_tokens=True)
  return tgt_text

# %% [markdown]
# ## Test 1
#
# # output:
# `['The test of your knowledge is your ability to convey it.',
#  'The ability to convey your knowledge is the ultimate test of your knowledge.',
#  'The ability to convey your knowledge is the most important test of your knowledge.',
#  'Your capacity to convey your knowledge is the ultimate test of it.',
#  'The test of your knowledge is your ability to communicate it.',
#  'Your capacity to convey your knowledge is the ultimate test of your knowledge.',
#  'Your capacity to convey your knowledge to another is the ultimate test of your knowledge.',
#  'Your capacity to convey your knowledge is the most important test of your knowledge.',
#  'The test of your knowledge is how well you can convey it.',
#  'Your capacity to convey your knowledge is the ultimate test.']`

# %%
num_beams = 10
num_return_sequences = 10

context = "The ultimate test of your knowledge is your capacity to convey it to another."
get_response(context, num_return_sequences, num_beams)
# Out:
# ['The test of your knowledge is your ability to convey it.',
#  'The ability to convey your knowledge is the ultimate test of your knowledge.',
#  'The ability to convey your knowledge is the most important test of your knowledge.',
#  'Your capacity to convey your knowledge is the ultimate test of it.',
#  'The test of your knowledge is your ability to communicate it.',
#  'Your capacity to convey your knowledge is the ultimate test of your knowledge.',
#  'Your capacity to convey your knowledge to another is the ultimate test of your knowledge.',
#  'Your capacity to convey your knowledge is the most important test of your knowledge.',
#  'The test of your knowledge is how well you can convey it.',
#  'Your capacity to convey your knowledge is the ultimate test.']

# %% [markdown]
# ## Test 2

# %%
num_beams = 10
num_return_sequences = 10

context = "The spread of Omicron has roiled financial markets and prompted governments around the world to tighten travel and workplace restrictions."
get_response(context, num_return_sequences, num_beams)
# Out:
# ['Governments around the world have tightened travel and workplace restrictions because of the spread of Omicron.',
#  'Governments around the world have tightened travel and workplace restrictions due to the spread of Omicron.',
#  'The spread of Omicron has caused governments around the world to tighten travel and workplace restrictions.',
#  'Governments around the world tightened travel and workplace restrictions because of the spread of Omicron.',
#  'Governments around the world have tightened travel and workplace restrictions in response to the spread of Omicron.',
#  'The spread of Omicron has led to tighter travel and workplace restrictions around the world.',
#  'The spread of Omicron has led to tighter travel and workplace restrictions.',
#  'Governments around the world tightened travel and workplace restrictions after the spread of Omicron.',
#  'The spread of Omicron has caused governments around the world to tighten travel and workplace rules.',
#  'The spread of Omicron has caused governments around the world to tighten travel and workplace regulations.']

# %% [markdown]
# ## Test 3

# %%
num_beams = 10
num_return_sequences = 10

context = "The Federal Reserve has spent most of 2021 saying that high inflation would be temporary."
get_response(context, num_return_sequences, num_beams)
# Out:
# ['The Federal Reserve said that high inflation would be temporary.',
#  'The Federal Reserve said high inflation would be temporary.',
#  'The Federal Reserve says that high inflation will be temporary.',
#  'The Fed said that high inflation would be temporary.',
#  'The Federal Reserve has said that high inflation would be temporary.',
#  'The Federal Reserve says high inflation will be temporary.',
#  'The Fed has said that high inflation would be temporary.',
#  'The Federal Reserve has said that high inflation will be temporary.',
#  'The Federal Reserve says that high inflation is temporary.',
#  'The Federal Reserve said that high inflation would be short-lived.']

# %% [markdown]
# ## Test 4

# %%
num_beams = 10
num_return_sequences = 10

context = "The good news is that the Fed can taper fast enough to let it raise interest rates in March."
get_response(context, num_return_sequences, num_beams)
# Out:
# ['The good news is that the Fed can raise interest rates in March.',
#  'The Fed will be able to raise interest rates in March.',
#  'The Fed can raise interest rates in March if it cuts back quickly.',
#  'The Fed will be able to raise interest rates in March because of the way it will be phased out.',
#  'The Fed will be able to raise interest rates in March because of the way it will be reduced.',
#  'The Fed will be able to raise interest rates in March if it is able to reduce its staff quickly.',
#  'The Fed will be able to raise interest rates in March if it is able to cut back quickly.',
#  'The Fed will be able to raise interest rates in March because of the speed at which they will be reduced.',
#  'The Fed will be able to raise interest rates in March because of the speed at which it will be phased out.',
#  'The Fed will be able to raise interest rates in March because of the speed at which it will be reduced.']

# %% [markdown]
# ## Test 5

# %%
num_beams = 10
num_return_sequences = 10

context = "Ever since the start of the trade war between America and China, investors, politicians and businesses have been trying to gauge how far and how fast the world's two biggest economies will decouple from each other."
get_response(context, num_return_sequences, num_beams)
# Out:
# ["Since the start of the trade war between America and China, investors, politicians and businesses have been trying to gauge how far and how fast the world's two biggest economies will decouple from each other.",
#  "Since the start of the trade war between America and China, investors, politicians and businesses have been trying to gauge how far and how fast the world's two biggest economies will decouple.",
#  "Since the start of the trade war between America and China, investors, politicians, and businesses have been trying to gauge how far and how fast the world's two biggest economies will decouple from each other.",
#  "Since the start of the trade war between America and China, investors, politicians and businesses have been trying to gauge how far and how fast the world's two biggest economies will decouple from each other",
#  "Since the start of the trade war between America and China, investors, politicians and businesses have been trying to gauge how far and how quickly the world's two biggest economies will decouple from each other.",
#  "Since the start of the trade war between America and China, investors, politicians, and businesses have been trying to gauge how far and how fast the world's two biggest economies will decouple.",
#  "Since the start of the trade war between America and China, investors, politicians and businesses have been trying to gauge how far and fast the world's two biggest economies will decouple from each other.",
#  "Since the start of the trade war between America and China, investors, politicians and businesses have been trying to gauge how far and how fast the world's two biggest economies will decouple from one another.",
#  "Since the beginning of the trade war between America and China, investors, politicians and businesses have been trying to gauge how far and how fast the world's two biggest economies will decouple from each other.",
#  "Since the start of the trade war between America and China, investors, politicians and businesses have been trying to gauge how far and how fast the world's two largest economies will decouple from each other."]

# %% [markdown]
# ## Test 6

# %%
num_beams = 10
num_return_sequences = 10

context = "Because of the success of bitcoin, the pioneering crypto-currency launched in 2008, many people associate blockchain primary with money and finance. But the applications of blockchain are much broader."
get_response(context, num_return_sequences, num_beams)
# Out:
# ['Because of the success of bitcoin, a lot of people associate it with money and finance.',
#  'Because of the success of bitcoin, many people associate it with money and finance.',
#  'Because of the success of the coin, many people associate it with money and finance.',
#  'Because of the success ofbitcoin, many people associate it with money and finance.',
#  'Because of the success of bitcoin, many people associate it with money and finance, but the applications of the technology are much broader.',
#  'Because of the success of the coin, many people associate it with money and finance, but the applications of the coin are much broader.',
#  'Because of the success of bitcoin, many people associate it with money and finance, but the applications of the coin are much broader.',
#  'Because of the success of the coin, a lot of people think of it as a money and finance tool.',
#  'Because of the success of bitcoin, a lot of people associate it with money and finance, but the applications of the technology are much broader.',
#  'Because of the success of the coin, many people associate it with money and finance, but the applications of the technology are much broader.']

# %% [markdown]
# ## Test 7

# %%
num_beams = 10
num_return_sequences = 10

context = "We also face increasingly challenging health problems on global scale, such as age-related diseases in developed countries and the growing need for affordable primary health-care in low-income countries."
get_response(context, num_return_sequences, num_beams)
# Out:
# ['Age-related diseases in developed countries and the need for affordable primary health-care in low-income countries are some of the health problems we face on a global scale.',
#  'Age-related diseases in developed countries and the growing need for affordable primary health-care in low-income countries are some of the health problems we face on a global scale.',
#  'Growing need for affordable primary health-care in low-income countries is one of the health problems we face on a global scale.',
#  'The growing need for affordable primary health-care in low-income countries is one of the health problems we face on a global scale.',
#  'Age-related diseases in developed countries and the need for affordable primary health-care in low-income countries are some of the health problems that we face on a global scale.',
#  'Growing need for affordable primary health-care in low-income countries and age-related diseases in developed countries are some of the health problems we face on a global scale.',
#  'Age-related diseases in developed countries and the growing need for affordable primary health-care in low-income countries are some of the health problems that we face on a global scale.',
#  'Age-related diseases in developed countries and the need for affordable primary health-care in low-income countries are some of the health problems we face.',
#  'Age-related diseases in developed countries and the growing need for affordable primary health-care in low-income countries are some of the health problems we face.',
#  'Age-related diseases in developed countries, and the need for affordable primary health-care in low-income countries, are some of the health problems we face on a global scale.']
